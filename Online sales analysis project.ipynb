# %%
df = pd.read_csv('Online Retail Dataset.csv')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 542009    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 542010    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 542011    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 542012    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 542013    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0        01/12/2010 8:26       2.55     17850.0  United Kingdom
# 1        01/12/2010 8:26       3.39     17850.0  United Kingdom
# 2        01/12/2010 8:26       2.75     17850.0  United Kingdom
# 3        01/12/2010 8:26       3.39     17850.0  United Kingdom
# 4        01/12/2010 8:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 542009  09/12/2011 12:50       0.85     12680.0          France
# 542010  09/12/2011 12:50       2.10     12680.0          France
# 542011  09/12/2011 12:50       4.15     12680.0          France
# 542012  09/12/2011 12:50       4.15     12680.0          France
# 542013  09/12/2011 12:50       4.95     12680.0          France
#
# [542014 rows x 8 columns]

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# Step 1: Data Loading
# Load the dataset into a Pandas DataFrame
df = pd.read_csv('Online Retail Dataset.csv')

# Step 2: Exploratory Data Analysis (EDA)
# Explore the dataset
print(df.head())
print(df.info())
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Step 3: Data Cleaning
# Handle missing values
df = df.dropna()

# Step 4: Feature Engineering
# Convert 'InvoiceDate' to datetime format using a specific format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%d/%m/%Y %H:%M')

# Extract date components
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Day'] = df['InvoiceDate'].dt.day


# Use K-means clustering for customer segmentation
# Use K-means clustering for customer segmentation
X = df[['Quantity', 'UnitPrice']]
kmeans = KMeans(n_clusters=3, n_init=10, random_state=42).fit(X)
df['Segment'] = kmeans.labels_



# Analyze trends in transaction data over time
monthly_sales = df.groupby(['Year', 'Month'])['Quantity'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_sales['Year'].astype(str) + '-' + monthly_sales['Month'].astype(str), y=monthly_sales['Quantity'], marker='o')
plt.title('Monthly Sales Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()


# Identify top-selling products(quantity)
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
print(top_products)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  01/12/2010 8:26       2.55     17850.0  United Kingdom
# 1  01/12/2010 8:26       3.39     17850.0  United Kingdom
# 2  01/12/2010 8:26       2.75     17850.0  United Kingdom
# 3  01/12/2010 8:26       3.39     17850.0  United Kingdom
# 4  01/12/2010 8:26       3.39     17850.0  United Kingdom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542014 entries, 0 to 542013
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    542014 non-null  object
#  1   StockCode    542014 non-null  object
#  2   Description  540560 non-null  object
#  3   Quantity     542014 non-null  int64
#  4   InvoiceDate  542014 non-null  object
#  5   UnitPrice    542014 non-null  float64
#  6   CustomerID   406934 non-null  float64
#  7   Country      542014 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None
#             Quantity      UnitPrice     CustomerID
# count  542014.000000  542014.000000  406934.000000
# mean        9.555285       4.611339   15287.724582
# std       218.060485      96.750980    1713.702628
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53215
# JUMBO BAG RED RETROSPOT               45066
# ASSORTED COLOUR BIRD ORNAMENT         35314
# WHITE HANGING HEART T-LIGHT HOLDER    34147
# PACK OF 72 RETROSPOT CAKE CASES       33656
# POPCORN HOLDER                        30504
# RABBIT NIGHT LIGHT                    27094
# MINI PAINT SET VINTAGE                25880
# PACK OF 12 LONDON TISSUES             25321
# PACK OF 60 PINK PAISLEY CAKE CASES    24204
# Name: Quantity, dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# Step 1: Data Loading
# Load the dataset into a Pandas DataFrame
df = pd.read_csv('Online Retail Dataset.csv')

# Step 2: Exploratory Data Analysis (EDA)
# Explore the dataset
print(df.head())
print(df.info())
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Step 3: Data Cleaning
# Handle missing values
df = df.dropna()

# Step 4: Feature Engineering
# Convert 'InvoiceDate' to datetime format using a specific format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%d/%m/%Y %H:%M')

# Extract date components
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Day'] = df['InvoiceDate'].dt.day

# Step 5: Customer Segmentation
# Use K-means clustering for customer segmentation
X = df[['Quantity', 'UnitPrice']]
kmeans = KMeans(n_clusters=3, n_init=10, random_state=42).fit(X)
df['Segment'] = kmeans.labels_

# Step 6: Calculate Total Revenue
df['TotalRevenue'] = df['Quantity'] * df['UnitPrice']


# Analyze trends in transaction data over time
monthly_revenue = df.groupby(['Year', 'Month'])['TotalRevenue'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_revenue['Year'].astype(str) + '-' + monthly_revenue['Month'].astype(str), y=monthly_revenue['TotalRevenue'], marker='o')
plt.title('Monthly Revenue Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()


# Identify top-selling products(revenue)
top_products = df.groupby('Description')['TotalRevenue'].sum().sort_values(ascending=False).head(10)
print(top_products)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  01/12/2010 8:26       2.55     17850.0  United Kingdom
# 1  01/12/2010 8:26       3.39     17850.0  United Kingdom
# 2  01/12/2010 8:26       2.75     17850.0  United Kingdom
# 3  01/12/2010 8:26       3.39     17850.0  United Kingdom
# 4  01/12/2010 8:26       3.39     17850.0  United Kingdom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542014 entries, 0 to 542013
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    542014 non-null  object
#  1   StockCode    542014 non-null  object
#  2   Description  540560 non-null  object
#  3   Quantity     542014 non-null  int64
#  4   InvoiceDate  542014 non-null  object
#  5   UnitPrice    542014 non-null  float64
#  6   CustomerID   406934 non-null  float64
#  7   Country      542014 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None
#             Quantity      UnitPrice     CustomerID
# count  542014.000000  542014.000000  406934.000000
# mean        9.555285       4.611339   15287.724582
# std       218.060485      96.750980    1713.702628
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# Description
# REGENCY CAKESTAND 3 TIER              132870.40
# WHITE HANGING HEART T-LIGHT HOLDER     93823.85
# JUMBO BAG RED RETROSPOT                83236.76
# PARTY BUNTING                          67687.53
# POSTAGE                                66710.24
# ASSORTED COLOUR BIRD ORNAMENT          56499.22
# RABBIT NIGHT LIGHT                     51137.80
# CHILLI LIGHTS                          45986.31
# PAPER CHAIN KIT 50'S CHRISTMAS         41500.48
# PICNIC BASKET WICKER 60 PIECES         39619.50
# Name: TotalRevenue, dtype: float64

# %%
df['TotalRevenue'] = df['Quantity'] * df['UnitPrice']

# %%
df['TotalRevenue']
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 542009    10.20
# 542010    12.60
# 542011    16.60
# 542012    16.60
# 542013    14.85
# Name: TotalRevenue, Length: 406934, dtype: float64

# %%
region_sales = df.groupby('Country')['TotalRevenue'].sum().sort_values(ascending=False)
plt.figure(figsize=(30, 6))
region_sales.plot(kind='bar')
plt.title('Sales Across Different Regions')
plt.xlabel('Country')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Segment', y='TotalRevenue')
plt.title('Box Plot: Distribution of TotalRevenue Across Customer Segments')
plt.xlabel('Customer Segment')
plt.ylabel('Total Revenue')
plt.show()

# %%
print(top_products)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              132870.40
# WHITE HANGING HEART T-LIGHT HOLDER     93823.85
# JUMBO BAG RED RETROSPOT                83236.76
# PARTY BUNTING                          67687.53
# POSTAGE                                66710.24
# ASSORTED COLOUR BIRD ORNAMENT          56499.22
# RABBIT NIGHT LIGHT                     51137.80
# CHILLI LIGHTS                          45986.31
# PAPER CHAIN KIT 50'S CHRISTMAS         41500.48
# PICNIC BASKET WICKER 60 PIECES         39619.50
# Name: TotalRevenue, dtype: float64
